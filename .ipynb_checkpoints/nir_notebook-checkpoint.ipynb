# %%
import pandas as pd

# %%
data_log = pd.read_csv('./r4.2/logon.csv')
data_log
# Out:
#                               id                 date     user       pc  \
# 0       {X1D9-S0ES98JV-5357PWMI}  01/02/2010 06:49:00  NGF0157  PC-6056
# 1       {G2B3-L6EJ61GT-2222RKSO}  01/02/2010 06:50:00  LRR0148  PC-4275
# 2       {U6Q3-U0WE70UA-3770UREL}  01/02/2010 06:53:04  LRR0148  PC-4124
# 3       {I0N5-R7NA26TG-6263KNGM}  01/02/2010 07:00:00  IRM0931  PC-7188
# 4       {D1S0-N6FH62BT-5398KANK}  01/02/2010 07:00:00  MOH0273  PC-6699
# ...                          ...                  ...      ...      ...
# 854854  {J8R2-H0FA17MQ-9304VEVQ}  05/17/2011 04:40:33  JDF0593  PC-6301
# 854855  {P3L5-A2AC53JU-4012GIRD}  05/17/2011 05:21:58  MLM0950  PC-9787
# 854856  {P2S0-P1JS62IF-2767BEPH}  05/17/2011 05:25:33  IRM0931  PC-7188
# 854857  {Z2U6-I8MA03NC-4963HKBH}  05/17/2011 06:23:48  IRM0931  PC-7188
# 854858  {T0U1-P7DT83QQ-7295ICZR}  05/17/2011 06:43:35  BJM0111  PC-6866
#
#        activity
# 0         Logon
# 1         Logon
# 2         Logon
# 3         Logon
# ...

# %%
data_mail = pd.read_csv('./r4.2/email.csv')
data_mail
# Out:
#                                id                 date     user       pc  \
# 0        {R3I7-S4TX96FG-8219JWFF}  01/02/2010 07:11:45  LAP0338  PC-5758
# 1        {R0R9-E4GL59IK-2907OSWJ}  01/02/2010 07:12:16  MOH0273  PC-6699
# 2        {G2B2-A8XY58CP-2847ZJZL}  01/02/2010 07:13:00  LAP0338  PC-5758
# 3        {A3A9-F4TH89AA-8318GFGK}  01/02/2010 07:13:17  LAP0338  PC-5758
# 4        {E8B7-C8FZ88UF-2946RUQQ}  01/02/2010 07:13:28  MOH0273  PC-6699
# ...                           ...                  ...      ...      ...
# 2629974  {L7U1-S3KK01XW-3123TPUC}  05/16/2011 20:54:18  HRL0540  PC-1117
# 2629975  {Q4Y3-X9HV77CL-3290SOZH}  05/16/2011 20:54:43  LAF0991  PC-4973
# 2629976  {L6B7-F7RU89CD-0355JGGE}  05/16/2011 21:08:12  LAF0991  PC-4973
# 2629977  {F4R9-W0OQ41HB-0157JSUE}  05/16/2011 21:15:35  JMW0638  PC-1397
# 2629978  {O8D9-S1AR98KA-2325CRWF}  05/16/2011 21:16:26  BCM0653  PC-5717
#
#                                                         to  \
# ...

# %%
all_logs = pd.read_csv('./logon+device+file_order_by_datetime.csv')
all_logs['day'] = pd.to_datetime(all_logs['date'])
all_logs
# Out:
#                                id             datetime     user       pc  \
# 0        {X1D9-S0ES98JV-5357PWMI}  2010-01-02 06:49:00  NGF0157  PC-6056
# 1        {G2B3-L6EJ61GT-2222RKSO}  2010-01-02 06:50:00  LRR0148  PC-4275
# 2        {U6Q3-U0WE70UA-3770UREL}  2010-01-02 06:53:04  LRR0148  PC-4124
# 3        {D1S0-N6FH62BT-5398KANK}  2010-01-02 07:00:00  MOH0273  PC-6699
# 4        {I0N5-R7NA26TG-6263KNGM}  2010-01-02 07:00:00  IRM0931  PC-7188
# ...                           ...                  ...      ...      ...
# 1705815  {J8R2-H0FA17MQ-9304VEVQ}  2011-05-17 04:40:33  JDF0593  PC-6301
# 1705816  {P3L5-A2AC53JU-4012GIRD}  2011-05-17 05:21:58  MLM0950  PC-9787
# 1705817  {P2S0-P1JS62IF-2767BEPH}  2011-05-17 05:25:33  IRM0931  PC-7188
# 1705818  {Z2U6-I8MA03NC-4963HKBH}  2011-05-17 06:23:48  IRM0931  PC-7188
# 1705819  {T0U1-P7DT83QQ-7295ICZR}  2011-05-17 06:43:35  BJM0111  PC-6866
#
#                        metadata
# 0         {"activity": "Logon"}
# ...

# %%
all_logs[(all_logs.datetime >= '2010-02-04') & (all_logs.datetime < '2010-02-05')]
# Out:
#                               id             datetime     user       pc  \
# 124201  {D2M1-F3CK37TZ-9298ORYB}  2010-02-04 00:20:41  KRV0372  PC-4155
# 124202  {R7B1-O9NV30FK-9727NAYR}  2010-02-04 00:22:05  KRV0372  PC-4155
# 124203  {R4M0-C5OK97LG-1179PNBR}  2010-02-04 00:28:33  ACC0042  PC-9348
# 124204  {A0R5-N9II78WV-4862VZMR}  2010-02-04 00:29:30  JHP0583  PC-9083
# 124205  {X5Z3-N5PG09XW-3376BDYY}  2010-02-04 00:34:32  ACC0042  PC-9348
# ...                          ...                  ...      ...      ...
# 129324  {I5H3-L4PF22GU-7865MFPK}  2010-02-04 23:40:15  GTD0219  PC-2531
# 129325  {W5F6-W5LM15TR-3766IWTZ}  2010-02-04 23:40:18  GTD0219  PC-2531
# 129326  {I5T3-P8UD67PG-6328KALR}  2010-02-04 23:44:11  GTD0219  PC-2531
# 129327  {F2T1-J3WL83WU-1921VGAT}  2010-02-04 23:45:39  SAK0375  PC-1586
# 129328  {B2Y9-J7ES56FV-6704XNUS}  2010-02-04 23:47:39  SAK0375  PC-1586
#
#                                                  metadata
# ...

# %%
def ahah(
    aa='bb'
):
    print(aa)

# %%
ahah()
# Out:
# bb

# %%
from sklearn.ensemble import IsolationForest
X = [[-1.1], [0.3], [0.5], [100]]
clf = IsolationForest(random_state=0).fit(X)
clf.predict([[0.1], [0], [90]])
# Out:
# array([ 1,  1, -1])
